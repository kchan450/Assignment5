# %% [markdown]
# ## **Assignment 5: Toddler Project**
#
#
# ### Objective
#
# In this assignment, two datasets are merged to create a comprehensive table that includes both sales data and unit costs.
#
# - Nike Sales Dataset (Nike_sales_2024) – Sourced from Kaggle, this dataset contains Nike's global sales data for 2024. (https://www.kaggle.com/datasets/ayushcx/nike-global-sales-data-2024)
#
# - Nike Unit Cost Dataset (Nike_unitcost) – it is generated from [www.mockaroo.com], providing unit cost for different Nike products.
#
# By joining these datasets, a more detailed sales table that includes both sales figures and unit costs, enabling a deeper analysis of profit or pricing strategy for each country/month.
# Also, it can help to identify any potential discrepancies in the Cost Dataset.

# %%
import pandas as pd
from datetime import date

# %%
cost = pd.read_csv("../Data/nike_unitCost.csv")  
sales = pd.read_csv("../Data/nike_sales_2024.csv")

# %% [markdown]
# # **Understand the data**
#
# Before create the BIG table, we understand the dataset, we break down the analysis into the following key aspects:
#
# 1. Total Rows and Column
# 2. Summary of Numeric and Categorical Columns
# 3. Null Data Information
# 4. Display the First 10 Rows of the Dataset

# %% [markdown]
# ## 1. Total Rows and Columns -  **
#
# ### nike_sales_2024.csv
# - The dataset contains **1,000 rows** and **10 columns**.
# - Each row represents a **sales record** for a Nike product.
#
# ### nike_cost.csv
# - The dataset contains **72 rows** and **3 columns**.
# - Each row represents a **unit cost** for a Nike product line.

# %%
print("1. Total rows and columns for nike_sales_2024:")
print("there are ", sales.shape[0], "rows")
print("there are ", sales.shape[1], "columns")

print("2. Total rows and columns for nike_unitCost:")
print("there are ", cost.shape[0], "rows")
print("there are ", cost.shape[1], "columns")
# Out:
# 1. Total rows and columns for nike_sales_2024:
# there are  1000 rows
# there are  10 columns
# 2. Total rows and columns for nike_unitCost:
# there are  70 rows
# there are  3 columns

# %% [markdown]
# ## 2. Summary of Numeric and Categorical Columns

# %%
print("Summary Statistics for nike_sales_2024:")
sales.describe(include ="all").round(2)
# Out:
# Summary Statistics for nike_sales_2024:
#            Month         Region Main_Category Sub_Category Product_Line  \
# count       1000           1000          1000         1000         1000
# unique        12              7             3           11           24
# top     December  Greater China     Equipment    Outerwear   Windrunner
# freq          96            161           352          125           65
# mean         NaN            NaN           NaN          NaN          NaN
# std          NaN            NaN           NaN          NaN          NaN
# min          NaN            NaN           NaN          NaN          NaN
# 25%          NaN            NaN           NaN          NaN          NaN
# 50%          NaN            NaN           NaN          NaN          NaN
# 75%          NaN            NaN           NaN          NaN          NaN
# max          NaN            NaN           NaN          NaN          NaN
#
#        Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  \
# count        1000     1000.00      1000.00                  1000.00
# unique          3         NaN          NaN                      NaN
# top        Budget         NaN          NaN                      NaN
# freq          348         NaN          NaN                      NaN
# mean          NaN    28498.95   5039576.41                    70.04
# std           NaN    12926.50   3267216.81                    11.75
# min           NaN     5028.00    287400.00                    50.00
# 25%           NaN    17554.25   2344675.00                    60.00
# 50%           NaN    28685.00   4328020.00                    71.00
# 75%           NaN    40026.00   7264942.50                    80.00
# max           NaN    49992.00  14864700.00                    90.00
#
#         Retail_Price
# count        1000.00
# unique           NaN
# top              NaN
# freq             NaN
# mean          176.32
# std            75.26
# min            50.00
# 25%           110.00
# 50%           180.00
# 75%           240.00
# max           300.00

# %%
print("Summary Statistics for nike_cost:")
cost.describe(include ="all").round(2)
# Out:
# Summary Statistics for nike_cost:
#        Product_Line Price_Tier  Unit_cost
# count            70         70      70.00
# unique           24          3        NaN
# top       KD Series     Budget        NaN
# freq              3         24        NaN
# mean            NaN        NaN      60.81
# std             NaN        NaN      23.96
# min             NaN        NaN      20.00
# 25%             NaN        NaN      41.25
# 50%             NaN        NaN      65.00
# 75%             NaN        NaN      82.00
# max             NaN        NaN      97.00

# %% [markdown]
# ## 3. Null Data Information
# - There is **no missing values** in **"Both"** dataset.

# %%
print("4. Print the summary about the Null Data information ")
sales.isna().sum()
# Out:
# 4. Print the summary about the Null Data information
# Month                      0
# Region                     0
# Main_Category              0
# Sub_Category               0
# Product_Line               0
# Price_Tier                 0
# Units_Sold                 0
# Revenue_USD                0
# Online_Sales_Percentage    0
# Retail_Price               0
# dtype: int64

# %%
print("4. Print the summary about the Null Data information ")
cost.isna().sum()
# Out:
# 4. Print the summary about the Null Data information
# Product_Line    0
# Price_Tier      0
# Unit_cost       0
# dtype: int64

# %% [markdown]
# ## 4. Display the First 5 Rows of the Dataset
# (the first 10 rows of the dataset is shown as below:)

# %%
## display the first 5 rows 

print("5. Display first 5th records for nike_sales_2024")
sales.head(5)
# Out:
# 5. Display first 5th records for nike_sales_2024
#       Month         Region Main_Category Sub_Category       Product_Line  \
# 0  November          India     Equipment         Bags           Gym Sack
# 1   January          India     Equipment  Accessories               Hats
# 2   October          India       Apparel         Tops        Tech Fleece
# 3  December  Greater China      Footwear      Cricket      Vapor Cricket
# 4       May  Greater China     Equipment        Socks  Performance Socks
#
#   Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  Retail_Price
# 0     Budget       48356     14506800                       73           300
# 1     Budget        9842      2066820                       50           210
# 2  Mid-Range       25079      1755530                       90            70
# 3    Premium       41404      8694840                       58           210
# 4    Premium       33569      5371040                       53           160

# %%
print("5. Display first 5th records for nike_unitCost")
cost.head(5)
# Out:
# 5. Display first 5th records for nike_unitCost
#   Product_Line Price_Tier  Unit_cost
# 0  Air Force 1     Budget         50
# 1   Air Jordan     Budget         21
# 2   Air Jordan  Mid-Range         39
# 3   Air Jordan    Premium         65
# 4      Air Max     Budget         66

# %% [markdown]
# # **Merge dataset**
#
# ## Which Join?
# **LEFT JOIN**
#
# It's better to keep all sales records and find out the missing costs rather than removing sales records (which would impact total revenue calculations), we should better use a LEFT JOIN
#
# ## Why?
# - Ensures all sales records are retained
# - If a product's unit cost is missing, it shows NaN
# - Helps identify products with missing cost values for further investigation
#
# ## Result
#
# - A total of 21 records have missing Unit_cost, displaying NaN values
# - All of these records fall under "Air Force 1 - Mid-Range" and "Air Force 1 - Premium," indicating the need to review and update the UnitCost file accordingly.

# %%
## Left Joins

# Perform a LEFT JOIN on Product_Line and Price_Tier
new = pd.merge(sales, cost, how = 'left', on=["Product_Line", "Price_Tier"])

# %%
missing_Count = new["Unit_cost"].isna().sum()
missing_Count
# Out:
# 21

# %%
missing_costs = new[new["Unit_cost"].isna()]
missing_costs
# Out:
#          Month          Region Main_Category Sub_Category Product_Line  \
# 133   December           India      Footwear    Lifestyle  Air Force 1
# 148   December          Europe      Footwear    Lifestyle  Air Force 1
# 163     August     South Korea      Footwear    Lifestyle  Air Force 1
# 236       July     South Korea      Footwear    Lifestyle  Air Force 1
# 257       July  Southeast Asia      Footwear    Lifestyle  Air Force 1
# 339       July           Japan      Footwear    Lifestyle  Air Force 1
# 362        May          Europe      Footwear    Lifestyle  Air Force 1
# 538        May     South Korea      Footwear    Lifestyle  Air Force 1
# 586        May         America      Footwear    Lifestyle  Air Force 1
# 593  September           Japan      Footwear    Lifestyle  Air Force 1
# 637       July  Southeast Asia      Footwear    Lifestyle  Air Force 1
# 649  September     South Korea      Footwear    Lifestyle  Air Force 1
# 668       July  Southeast Asia      Footwear    Lifestyle  Air Force 1
# 688    October           India      Footwear    Lifestyle  Air Force 1
# 698   February           India      Footwear    Lifestyle  Air Force 1
# 722     August         America      Footwear    Lifestyle  Air Force 1
# 774        May          Europe      Footwear    Lifestyle  Air Force 1
# 814  September           Japan      Footwear    Lifestyle  Air Force 1
# 889       June   Greater China      Footwear    Lifestyle  Air Force 1
# 911    October   Greater China      Footwear    Lifestyle  Air Force 1
# 946       July     South Korea      Footwear    Lifestyle  Air Force 1
#
#     Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  \
# 133  Mid-Range       28038      1401900                       63
# 148  Mid-Range       49565      9417350                       90
# 163    Premium        5580      1339200                       66
# 236  Mid-Range       23339      7001700                       84
# 257    Premium        5233       313980                       55
# 339    Premium       32062      4809300                       52
# 362    Premium       18939      4355970                       78
# 538    Premium       24535      4170950                       71
# 586  Mid-Range        7516      1202560                       75
# 593  Mid-Range       17902      1611180                       65
# 637    Premium       24571      4668490                       76
# 649  Mid-Range       45981      7816770                       69
# 668  Mid-Range       48935     11255050                       75
# 688  Mid-Range       48761      6826540                       86
# 698    Premium       33324      5665080                       85
# 722  Mid-Range       20762      3944780                       59
# 774    Premium       30306      6061200                       57
# 814  Mid-Range       20109      1005450                       74
# 889  Mid-Range        7535      2185150                       52
# 911    Premium       32471      7468330                       87
# 946  Mid-Range       42093      5472090                       53
#
#      Retail_Price  Unit_cost
# 133            50        NaN
# 148           190        NaN
# 163           240        NaN
# 236           300        NaN
# 257            60        NaN
# 339           150        NaN
# 362           230        NaN
# 538           170        NaN
# 586           160        NaN
# 593            90        NaN
# 637           190        NaN
# 649           170        NaN
# 668           230        NaN
# 688           140        NaN
# 698           170        NaN
# 722           190        NaN
# 774           200        NaN
# 814            50        NaN
# 889           290        NaN
# 911           230        NaN
# 946           130        NaN

# %% [markdown]
# # **Result file**
#
# The records with missing unit costs have been saved to a new file for further investigation.

# %%
# Generate a new filename with today's date
file_name = "MissingUnitCost_Carol_Chan_"+ date.today().isoformat()+'.csv'

# Save the DataFrame to a CSV file
missing_costs.to_csv("../Result/"+ file_name)
